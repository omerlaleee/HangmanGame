-- %% [markdown]
-- # [dbo].[Words]

-- %%
USE [HW2]
GO

-- %%
/****** Object:  Table [dbo].[Words]    Script Date: 06/04/2022 02:53:15 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Words](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Word] [varchar](max) NOT NULL,
	[Hint] [varchar](max) NOT NULL,
 CONSTRAINT [PK_Words] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %%
SET IDENTITY_INSERT [dbo].[Words] ON 
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (40, N'el elden üstündür', N'Bir Atasözü')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (41, N'portakal', N'Bir Meyve Çesidi')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (42, N'mercedes', N'Bir Araba Markasi')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (43, N'bilgisayar', N'Bir Elektronik Esya')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (45, N'karpuz', N'Bir Yaz Meyvesi')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (46, N'vezir parmagi', N'Bir Tatli Çesidi')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (47, N'sefiller', N'Victor Hugo''nun Roman Türünde Bir Eseri')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (48, N'netflix', N'Bir Film Izleme Platformu')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (49, N'ethereum', N'Bir Kripto Para Birimi')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (50, N'klavye', N'Bir Bilgisayar Ekipmani')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (51, N'ivme', N'Hizin Zamana Göre Türevi')
INSERT [dbo].[Words] ([Id], [Word], [Hint]) VALUES (52, N'matara', N'Genellikle Askerlerin Kullandigi Su Kabi')
SET IDENTITY_INSERT [dbo].[Words] OFF
GO
